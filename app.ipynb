# %%
import streamlit as st
import cv2
import numpy as np
from PIL import Image
# Import Mask R-CNN libraries (adjust paths based on your setup)
from mrcnn.config import Config
from mrcnn.model import MaskRCNN
import mrcnn.visualize as visualize
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3248\2850295338.py in <module>
#       5 # Import Mask R-CNN libraries (adjust paths based on your setup)
#       6 from mrcnn.config import Config
# ----> 7 from mrcnn.model import MaskRCNN
#       8 import mrcnn.visualize as visualize
#
# ~\anaconda3\lib\site-packages\mrcnn\model.py in <module>
#      22 import keras.backend as K
#      23 import keras.layers as KL
# ---> 24 import keras.engine as KE
#      25 import keras.models as KM
#      26
#
# ModuleNotFoundError: No module named 'keras.engine'

# %%
import tensorflow as tf
import keras

# %%
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.14.0

# %%
print("Standalone Keras version:", keras.__version__)
# Out:
# Standalone Keras version: 2.14.0
